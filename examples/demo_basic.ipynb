# %% [markdown]
# # Jet Observable Library Demo\n\nMinimal usage of the v0.1 API.

# %%
import numpy as np\nfrom jet_observables.jet import Jet\nfrom jet_observables.observables.shapes import jet_width

# %%
particles = np.array([\n    [40.0, 20.0, 5.0, 34.0],\n    [25.0, 7.0, 4.0, 23.0],\n])\njet = Jet(particles)\njet.pt(), jet.mass(), jet.eta(), jet.phi(), jet_width(jet)
