# %% [markdown]
# # HEPSIM Evaluation Template
#
# One-paragraph summary of approach and findings goes here (required for submission readability).

# %% [markdown]
# ## A. Data loading and zero-padding contract
# - Load QG_jets_*.npz
# - Apply canonical mask `(pt > 0) & (pdgid != 0)`
# - Report multiplicities and leading-constituent distributions

# %% [markdown]
# ## B. Jet observables
# Compute and compare: mass, width, pTD (and optional e2/tau1).

# %% [markdown]
# ## C. Boost to jet rest frame
# - Use robust Lorentz boost utility
# - Print residual `||sum p'⃗||` diagnostics

# %%
comparison_table = [
    {'frame': 'lab', 'auc': None, 'notes': 'fill after training'},
    {'frame': 'rest', 'auc': None, 'notes': 'fill after training'},
]
comparison_table

# %% [markdown]
# ## D. Quark vs gluon classification
# Include ROC, AUC, confusion matrix, and identify the single most discriminating feature.
